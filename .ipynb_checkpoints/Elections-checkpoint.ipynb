# %% [markdown]
# # Elections South Africa Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_curve, roc_auc_score, classification_report, confusion_matrix, f1_score, accuracy_score


import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_excel('National.xlsx', engine='openpyxl')

# %%
data.head()
# Out:
#    Unnamed: 0                 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         NaN                        NaN         NaN         NaN         NaN
# 1         NaN                 Party Name         NaN         NaN         NaN
# 2         NaN           UMKHONTO WESIZWE         NaN         NaN         NaN
# 3         NaN  AFRICAN NATIONAL CONGRESS         NaN         NaN         NaN
# 4         NaN      INKATHA FREEDOM PARTY         NaN         NaN         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 0         NaN         NaN         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN         NaN  Party Abbr          NaN
# 2         NaN         NaN         NaN         NaN        M.K.          NaN
# 3         NaN         NaN         NaN         NaN         ANC          NaN
# 4         NaN         NaN         NaN         NaN         IFP          NaN
#
#   Unnamed: 11  Unnamed: 12  Unnamed: 13 Unnamed: 14
# 0         NaN          NaN          NaN         NaN
# 1       Votes          NaN          NaN     % Votes
# 2      100564          NaN          NaN    0.438606
# 3       48937          NaN          NaN    0.213437
# 4       40454          NaN          NaN    0.176439

# %%
data.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
data[~data['Unnamed: 2'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13, Unnamed: 14]
# Index: []

# %%
data.head()
# Out:
#                   Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0                        NaN         NaN         NaN         NaN         NaN
# 1                 Party Name         NaN         NaN         NaN         NaN
# 2           UMKHONTO WESIZWE         NaN         NaN         NaN         NaN
# 3  AFRICAN NATIONAL CONGRESS         NaN         NaN         NaN         NaN
# 4      INKATHA FREEDOM PARTY         NaN         NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10 Unnamed: 11  \
# 0         NaN         NaN         NaN         NaN          NaN         NaN
# 1         NaN         NaN         NaN  Party Abbr          NaN       Votes
# 2         NaN         NaN         NaN        M.K.          NaN      100564
# 3         NaN         NaN         NaN         ANC          NaN       48937
# 4         NaN         NaN         NaN         IFP          NaN       40454
#
#    Unnamed: 12  Unnamed: 13 Unnamed: 14
# 0          NaN          NaN         NaN
# 1          NaN          NaN     % Votes
# 2          NaN          NaN    0.438606
# 3          NaN          NaN    0.213437
# 4          NaN          NaN    0.176439

# %%
data.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13, Unnamed: 14]
# Index: []
